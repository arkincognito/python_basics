# %% [markdown]
# <a href="https://colab.research.google.com/github/arkincognito/python_basics/blob/main/matplotlib_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Link to matplotlib color map guide post
# https://frhyme.github.io/python-lib/matplotlib_extracting_color_from_cmap/

# %% [markdown]
# #Link to Seaborn tutorial with titanic data
#
# https://gist.github.com/mwaskom/8224591
#
# It also shows ways to set the palettes up, so the whole notebook has dedicated colors for each category.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from IPython.display import set_matplotlib_formats
mpl.rcParams['axes.unicode_minus'] = False
set_matplotlib_formats('retina')

import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Korean Fonts
# Initial font will break if Korean characters are used.

# %%
# !python --version
def current_font():
  print(f"설정 폰트 글꼴: {plt.rcParams['font.family']}, 설정 폰트 사이즈: {plt.rcParams['font.size']}")  # 파이썬 3.6 이상 사용가능하다
        
current_font()
# Out:
# Python 3.6.9
# 설정 폰트 글꼴: ['NanumGothic Eco'], 설정 폰트 사이즈: 10.0

# %% [markdown]
# Download Korean Font and set as font family

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
plt.rc('font', size=10)
# Out:
# NanumGothic Eco

# %% [markdown]
# Rebuild the font_manager, and restart the kernel(not sure why though)

# %%
fm._rebuild()

# %% [markdown]
# # Font Setup
# We can setup font size and font color for the plots.
#
# Setting font color is usefull when using dark background.

# %%
SMALL_SIZE = 12
MEDIUM_SIZE = 15
LARGE_SIZE = 18

plt.rc('font', size=SMALL_SIZE) # Default text sizes
plt.rc('axes', titlesize=SMALL_SIZE) # Axes title fontsize
plt.rc('axes', labelsize=MEDIUM_SIZE) # x and y labels' fontsize
plt.rc('xtick', labelsize=SMALL_SIZE) # x tick label size
plt.rc('ytick', labelsize=SMALL_SIZE) # y tick label size
plt.rc('legend', fontsize=SMALL_SIZE) # Legend fontsize
plt.rc('figure', titlesize=LARGE_SIZE) # Figure title size

# %% [markdown]
# # Color Parameters
#
# *   List of named colors for MPL is located here: https://matplotlib.org/examples/color/named_colors.html

# %%
# sns.set_style('whitegrid') #style must be one of white, dark, whitegrid, darkgrid, ticks
# sns.set(rc={'figure.facecolor':'k'}) 

COLOR = 'white'
mpl.rcParams['text.color'] = 'black' # Default text color(including legend)
mpl.rcParams['axes.labelcolor'] = COLOR # Axes label color
mpl.rcParams['axes.titlecolor'] = COLOR # Subplot Title Color
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR

# %% [markdown]
# ## Additional color related parameters

# %%
color_para = []
for key in mpl.rcParams.keys():
  if 'color' in key:
    color_para.append(key) 
color_para
# Out:
# ['axes.edgecolor',
#  'axes.facecolor',
#  'axes.labelcolor',
#  'axes.titlecolor',
#  'boxplot.boxprops.color',
#  'boxplot.capprops.color',
#  'boxplot.flierprops.color',
#  'boxplot.flierprops.markeredgecolor',
#  'boxplot.flierprops.markerfacecolor',
#  'boxplot.meanprops.color',
#  'boxplot.meanprops.markeredgecolor',
#  'boxplot.meanprops.markerfacecolor',
#  'boxplot.medianprops.color',
#  'boxplot.whiskerprops.color',
#  'figure.edgecolor',
#  'figure.facecolor',
#  'grid.color',
#  'hatch.color',
#  'legend.edgecolor',
#  'legend.facecolor',
#  'lines.color',
#  'lines.markeredgecolor',
#  'lines.markerfacecolor',
#  'mpl_toolkits.legacy_colorbar',
#  'patch.edgecolor',
#  'patch.facecolor',
#  'patch.force_edgecolor',
#  'pdf.inheritcolor',
#  'savefig.edgecolor',
#  'savefig.facecolor',
#  'scatter.edgecolors',
#  'text.color',
#  'xtick.color',
#  'ytick.color']

# %% [markdown]
# # Data for the practice

# %%
url = 'https://bit.ly/dsa-04-health'
data = pd.read_csv(url)
print(data.shape)
data.head()
# Out:
# (1000, 34)
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  ...  치아마모증유무  제3대구치(사랑니)이상   치석   데이터공개일자
# 0  2016   465969     1            8  ...      NaN           NaN  2.0  20171219
# 1  2016   565871     1           10  ...      NaN           NaN  NaN  20171219
# 2  2016   115718     2           11  ...      NaN           NaN  0.0  20171219
# 3  2016   767524     1            6  ...      NaN           NaN  NaN  20171219
# 4  2016   482178     2            9  ...      NaN           NaN  0.0  20171219
#
# [5 rows x 34 columns]

# %% [markdown]
# # Palette Setup

# %%
# Sets specific colorcode to each category
pal_sex = {1:"#4682B4", 2:"#CD5C5C"} # Used for 성별코드

# %% [markdown]
# # sns.countplot

# %%
sns.countplot(data=data, x='성별코드', palette=pal_sex,)
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.countplot(data=data, x='시도코드')

# %% [markdown]
# # Multiple subplots in a figure

# %%
#Multiple subplots in a figure
figure,((ax1, ax2)) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(15,3)
sns.countplot(data=data, x='시도코드', ax=ax1)
sns.countplot(data=data, x='성별코드', ax=ax2)

# %%
#Subplots unpacked into axes
figure,((ax1,ax2),(ax3,ax4),(ax5,ax6)) = plt.subplots(nrows=3, ncols=2)

# %%
#Set of axes can be made
figure, axes = plt.subplots(nrows=4, ncols=3)

# %% [markdown]
# # Palette management
# Seaborn plots have presets of colors as palette variable.

# %%
#color.adobe.com
pal_names = ['rainbow', 'colorblind', 'Blues', 'autumn', 'coolwarm_r', 'Set1', 'Set2', 'Set3']
for i in pal_names:
  palette = sns.color_palette(i, 7)
  sns.palplot(palette)

# %% [markdown]
# # Setting differents sizes for subplots
#
# Notice that hue will separate the values according to the category

# %%
from matplotlib import gridspec

# Set the whole figure size
figure = plt.figure(figsize=(15,15))

# Set the subplot numbers, height_ratios, and width_ratios
gs = gridspec.GridSpec(nrows=2, ncols=1, height_ratios=[2,3], width_ratios=[1])

# Assign gridspec to the appropriate subplot
ax0=plt.subplot(gs[0])
ax1=plt.subplot(gs[1])

# Use the subplot as the variable for ax
sns.countplot(data=data, x='시도코드', hue='성별코드', ax=ax0, palette=pal_sex)
sns.countplot(data=data, y='시도코드', hue='성별코드', ax=ax1, palette=pal_sex)

# Output
# Additionally, if use plt.savefig('directory/filename.svg'), the figure will be saved.
ax0.set_title('Vertical')
ax1.set_title('Horizontal')
plt.show()

# %% [markdown]
# # sns.histplot

# %%
fig, axes = plt.subplots(nrows=5, ncols=1)
fig.set_size_inches(11,25)
hue_order = {0:'흡연 안 함', 1:'금연 중', 2:'흡연 중'}
sns.histplot(data, x='허리둘레', hue='흡연상태', multiple='stack', kde=True, ax=axes[0])
sns.histplot(data, x='허리둘레', hue='흡연상태', multiple='fill', ax=axes[1])
sns.kdeplot(data=data, x='허리둘레', hue='흡연상태', ax=axes[2])
sns.kdeplot(data=data, x='허리둘레', hue='흡연상태', multiple='fill', ax=axes[3])
sns.kdeplot(data=data, x='허리둘레', hue='흡연상태', multiple='stack', ax=axes[4])
plt.show()

# %% [markdown]
# # Distribution plot by category
# Multiple plots without subplot assignment will overlay all the subplots into one plot.
#
# Labels will automatically show if the plt.legend() is called and the title of the legend is assignable.

# %%
one = data[data['흡연상태']==1]
two = data[data['흡연상태']==2]
three = data[data['흡연상태']==3]

plt.figure(figsize=(10,7))

dist_one = sns.distplot(one['허리둘레'], hist=False, label='흡연 안 함')
dist_two = sns.distplot(two['허리둘레'], hist=False, label='금연 중')
dist_three = sns.distplot(three['허리둘레'], hist=False, label='흡연 중')

mpl.rcParams['text.color'] = 'black'
plt.legend(title='흡연 상태')
plt.show()

# %% [markdown]
# # sns.barplot
# sns.barplot(data=, x=, y=something_w/_numerical_values)
#
# Default estimator is mean

# %%
fig = plt.figure(figsize=(12,5))
sns.barplot(data=data, x='시도코드', y='수축기혈압', color='b', palette='rainbow')
# color is overridden if palette is used.
plt.show()

# %% [markdown]
# ## Change the estimator to draw out other statistical values

# %%
fig = plt.figure(figsize=(12,5))
sns.barplot(data=data, x='시도코드', y='구강검진 수검여부', estimator=np.sum)
plt.show()

# %% [markdown]
# ## Change orientation of the plot by swapping x,y and set orient

# %%
fig = plt.figure(figsize=(5,12))
sns.barplot(data=data, x='구강검진 수검여부', y='연령대코드(5세단위)', hue='성별코드', estimator=np.sum, orient='h', palette=pal_sex)
plt.show()

# %% [markdown]
# # sns.boxplot
# Center of the box is 50 percentile(median).
#
# Box surrounds 25~75 percentile.
#
# Top tick and bottom tick shows 95% confidence interval.
#
# Points outside the boxplot shows outliers.

# %%
fig = plt.figure(figsize=(12,5))
sns.boxplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', palette='BuPu')
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
sns.boxplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', palette=pal_sex, hue='성별코드')
plt.show()

# %% [markdown]
# # sns.violinplot

# %%
fig = plt.figure(figsize=(25,5))
sns.violinplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', palette=pal_sex, saturation=1, hue='성별코드')
plt.show()

# %% [markdown]
# ## split=True
#
# This will merge the two hue categories and express in one.
#
# ONLY WORKS WHEN hue is set for a binary category.

# %%
fig = plt.figure(figsize=(15,5))
sns.violinplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', palette=pal_sex, saturation=1, hue='성별코드',\
               split=True, inner='quartile', linewidth=1, scale_hue=True)
sns.despine(left=True)
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
sns.violinplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', palette=pal_sex, saturation=1, hue='성별코드',\
               split=True, inner='box', dodge=False )
sns.despine(left=True)
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
sns.violinplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', palette='Set1', hue='성별코드')
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
sns.pointplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', palette=pal_sex, hue='성별코드', linestyles=[':','-'])
plt.show()

# %% [markdown]
# # sns.lineplot

# %%
fig = plt.figure(figsize=(15,5))
sns.lineplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', \
             palette=pal_sex, hue='성별코드', ci=None)
plt.show()

# %% [markdown]
# # sns.scatterplot

# %%
fig = plt.figure(figsize=(15,12))
target = data[data['식전혈당(공복혈당)']<150]
sns.scatterplot(data=target, x='식전혈당(공복혈당)', y='수축기혈압', hue='허리둘레', size='총콜레스테롤'\
                , sizes=(30,550), palette='RdPu', alpha=1)
plt.show()

# %%
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
C = np.random.randint(0, 5, 100)

figsize = (4,4)
title_fontsize = 20
label_fontsize = 15
dotsize = 15

fig = plt.figure(figsize = figsize)
plt.scatter(X,Y, s = dotsize)
plt.show()

# %%
cmap_lst = [plt.cm.rainbow, plt.cm.Blues, plt.cm.autumn, plt.cm.RdYlGn]

f, axes = plt.subplots(1, 4, sharex=True, sharey=True)
f.set_size_inches((16,3.5))
for i in range(0,4):
    axes[i].scatter(X, Y, c = C, cmap = cmap_lst[i], s = dotsize, alpha = 0.75)
    axes[i].set_title('cmap :' + cmap_lst[i].name)
plt.show()

# %% [markdown]
# ## To show the value by color or dotsize
#
# Set the value into color c (or dotsize s), plug in the color map.

# %%
sample_size = 500
color_num = 50

X = np.random.normal(0, 1, sample_size)
Y = np.random.normal(0, 1, sample_size)

# We could use both integer values and float values for the color and size
C = np.random.randint(0, color_num, sample_size) # picking sample_size of random numbers in between 0 and color_num.
S = np.random.randint(10, 200, sample_size)

plt.figure(figsize=(12, 8))
plt.scatter(X, Y, c=C, s=S, cmap=plt.cm.Reds, alpha=1)
plt.colorbar(label='color')
plt.show()

# %% [markdown]
# ## To show the category by color
#
# Choose select number of colors from the color map, and plug that in into the cmap.
#
# cmap = plt.cm.get_cmap('rainbow', color_num)

# %%
sample_size = 1000
color_num = 3

X = np.random.normal(0, 1, sample_size)
Y = np.random.normal(0, 1, sample_size)

C = np.random.randint(0, color_num, sample_size)

plt.figure(figsize=(12, 4))
plt.scatter(X, Y, c=C, s=20, cmap=plt.cm.get_cmap('rainbow', color_num), alpha=0.5)
plt.colorbar(ticks=range(color_num), format='color: %d', label='color')
plt.show()

# %% [markdown]
# ## To show category by Legend
#
# Plot each category seperately, assign each of them label, and show legend.

# %%
sample_size = 1000
color_num = 3

plt.figure(figsize = (12,6))
X = np.vstack([np.random.normal(i, 1, sample_size // color_num) for i in range(color_num)])
Y = np.vstack([np.random.normal(i, 1, sample_size // color_num) for i in range(color_num)])

# c_list = [plt.cm.rainbow(a) for a in np.linspace(0.0, 1.0, 3)]
## 'c' argument looks like a single numeric RGB or RGBA sequence,
## which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'. 
## Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

c_list = [[plt.cm.rainbow(a)] for a in np.linspace(0.0, 1.0, color_num)] # Using 2-D array with a single row to avoid alert.

for i in range(3):
    plt.scatter(X[i], Y[i], c = c_list[i], label = 'group {}'.format(int(i+1)), alpha = 0.7)
plt.legend()
plt.show()

# %% [markdown]
# #Other examples
# https://seaborn.pydata.org/examples/grouped_violinplots.html
